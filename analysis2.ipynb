# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(8, 4))

c = [
    "#c39eff",
    "#8babff",
    "#00b8ff",
    "#00c3ff",
    "#00cbff",
    "#00d0f1",
    "#00d2c6",
    "#00d292",
    "#00cf59",
    "#57c900",
]

data_50000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-50000M.dat") if x.startswith("MEASURE ")])
# data_20000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-20000M.dat") if x.startswith("MEASURE ")])
# data_15000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-15000M.dat") if x.startswith("MEASURE ")])
data_10000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-10000M.dat") if x.startswith("MEASURE ")])
# data_9000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-9000M.dat") if x.startswith("MEASURE ")])
# data_8000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-8000M.dat") if x.startswith("MEASURE ")])
# data_7000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-7000M.dat") if x.startswith("MEASURE ")])
# data_6000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-6000M.dat") if x.startswith("MEASURE ")])
data_5000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-5000M.dat") if x.startswith("MEASURE ")])
data_4000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-4000M.dat") if x.startswith("MEASURE ")])
# data_3000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-3000M.dat") if x.startswith("MEASURE ")])
# data_2000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-2000M.dat") if x.startswith("MEASURE ")])

data_50000M = data_50000M[(data_50000M[:, 1] == 0) | (data_50000M[:, 1] > 0.01*data_50000M[:, 1].max())]
data_10000M = data_10000M[(data_10000M[:, 1] == 0) | (data_10000M[:, 1] > 0.01*data_10000M[:, 1].max())]
data_5000M = data_5000M[(data_5000M[:, 1] == 0) | (data_5000M[:, 1] > 0.01*data_5000M[:, 1].max())]
data_4000M = data_4000M[(data_4000M[:, 1] == 0) | (data_4000M[:, 1] > 0.01*data_4000M[:, 1].max())]

ax.plot(data_50000M[:, 0], data_50000M[:, 1] / 1e9, c=c[0], label="50 GB")
# ax.plot(data_20000M[:, 0], data_20000M[:, 1] / 1e9, c=c[1], label="20 GB")
# ax.plot(data_15000M[:, 0], data_15000M[:, 1] / 1e9, c=c[2], label="15 GB")
ax.plot(data_10000M[:, 0], data_10000M[:, 1] / 1e9, c=c[3], label="10 GB")
# ax.plot(data_9000M[:, 0], data_9000M[:, 1] / 1e9, c=c[4], label="9 GB")
# ax.plot(data_8000M[:, 0], data_8000M[:, 1] / 1e9, c=c[5], label="8 GB")
# ax.plot(data_7000M[:, 0], data_7000M[:, 1] / 1e9, c=c[6], label="7 GB")
# ax.plot(data_6000M[:, 0], data_6000M[:, 1] / 1e9, c=c[7], label="6 GB")
ax.plot(data_5000M[:, 0], data_5000M[:, 1] / 1e9, c=c[8], label="5 GB")
ax.plot(data_4000M[:, 0], data_4000M[:, 1] / 1e9, c="#ff7800", label="4 GB")
# ax.plot(data_3000M[:, 0], data_3000M[:, 1] / 1e9, c="#ff7800", label="3 GB")
# ax.plot(data_2000M[:, 0], data_2000M[:, 1] / 1e9, c="#ff0006", label="2 GB")

ax.set_xlim(0, 80)
ax.set_ylim(0, 10)
ax.set_xlabel("time (seconds)")
ax.set_ylabel("memory (GB) in Unique Set Size (USS)")
ax.set_title("Python 3.12.1")

ax.legend(title="cap on memory", loc="upper right")
fig.savefig("gcbox-python.pdf")

# %%
fig, ax = plt.subplots(figsize=(8, 4))

c = [
    "#c39eff",
    "#8babff",
    "#00b8ff",
    "#00c3ff",
    "#00cbff",
    "#00d0f1",
    "#00d2c6",
    "#00d292",
    "#00cf59",
    "#57c900",
]

data_50000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-50000M-10x.dat") if x.startswith("MEASURE ")])
# data_20000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-20000M-10x.dat") if x.startswith("MEASURE ")])
# data_15000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-15000M-10x.dat") if x.startswith("MEASURE ")])
data_10000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-10000M-10x.dat") if x.startswith("MEASURE ")])
data_9000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-9000M-10x.dat") if x.startswith("MEASURE ")])
data_8000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-8000M-10x.dat") if x.startswith("MEASURE ")])
# data_7000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-7000M-10x.dat") if x.startswith("MEASURE ")])
# data_6000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-6000M-10x.dat") if x.startswith("MEASURE ")])
# data_5000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-5000M-10x.dat") if x.startswith("MEASURE ")])
# data_4000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-4000M-10x.dat") if x.startswith("MEASURE ")])
# data_3000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-3000M-10x.dat") if x.startswith("MEASURE ")])
# data_2000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-python-2000M-10x.dat") if x.startswith("MEASURE ")])

data_50000M = data_50000M[(data_50000M[:, 1] == 0) | (data_50000M[:, 1] > 0.01*data_50000M[:, 1].max())]
data_10000M = data_10000M[(data_10000M[:, 1] == 0) | (data_10000M[:, 1] > 0.01*data_10000M[:, 1].max())]
data_9000M = data_9000M[(data_9000M[:, 1] == 0) | (data_9000M[:, 1] > 0.01*data_9000M[:, 1].max())]
data_8000M = data_8000M[(data_8000M[:, 1] == 0) | (data_8000M[:, 1] > 0.01*data_8000M[:, 1].max())]

ax.plot(data_50000M[:, 0], data_50000M[:, 1] / 1e9, c=c[0], label="50 GB")
# ax.plot(data_20000M[:, 0], data_20000M[:, 1] / 1e9, c=c[1], label="20 GB")
# ax.plot(data_15000M[:, 0], data_15000M[:, 1] / 1e9, c=c[2], label="15 GB")
ax.plot(data_10000M[:, 0], data_10000M[:, 1] / 1e9, c=c[3], label="10 GB")
ax.plot(data_9000M[:, 0], data_9000M[:, 1] / 1e9, c=c[6], label="9 GB")
ax.plot(data_8000M[:, 0], data_8000M[:, 1] / 1e9, c="#ff7800", label="8 GB")
# ax.plot(data_7000M[:, 0], data_7000M[:, 1] / 1e9, c=c[6], label="7 GB")
# ax.plot(data_6000M[:, 0], data_6000M[:, 1] / 1e9, c=c[7], label="6 GB")
# ax.plot(data_5000M[:, 0], data_5000M[:, 1] / 1e9, c=c[8], label="5 GB")
# ax.plot(data_4000M[:, 0], data_4000M[:, 1] / 1e9, c="#ff7800", label="4 GB")
# ax.plot(data_3000M[:, 0], data_3000M[:, 1] / 1e9, c="#ff7800", label="3 GB")
# ax.plot(data_2000M[:, 0], data_2000M[:, 1] / 1e9, c="#ff0006", label="2 GB")

ax.set_xlim(0, 80)
ax.set_ylim(0, 10)
ax.set_xlabel("time (seconds)")
ax.set_ylabel("memory (GB) in Unique Set Size (USS)")
ax.set_title("Python 3.12.1 with gc.threshold × 10")

ax.legend(title="cap on memory", loc="upper right")
fig.savefig("gcbox-python-10x.pdf")

# %%
fig, ax = plt.subplots(figsize=(8, 4))

c = [
    "#c39eff",
    "#8babff",
    "#00b8ff",
    "#00c3ff",
    "#00cbff",
    "#00d0f1",
    "#00d2c6",
    "#00d292",
    "#00cf59",
    "#57c900",
]

data_50000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-julia-50000M.dat") if x.startswith("MEASURE ")])
data_20000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-julia-20000M.dat") if x.startswith("MEASURE ")])
data_15000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-julia-15000M.dat") if x.startswith("MEASURE ")])
data_10000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-julia-10000M.dat") if x.startswith("MEASURE ")])
data_9000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-julia-9000M.dat") if x.startswith("MEASURE ")])
data_8000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-julia-8000M.dat") if x.startswith("MEASURE ")])
data_7000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-julia-7000M.dat") if x.startswith("MEASURE ")])
data_6000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-julia-6000M.dat") if x.startswith("MEASURE ")])
data_5000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-julia-5000M.dat") if x.startswith("MEASURE ")])
data_4000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-julia-4000M.dat") if x.startswith("MEASURE ")])
data_3000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-julia-3000M.dat") if x.startswith("MEASURE ")])
data_2000M = np.array([list(map(float, x.split()[1:])) for x in open("data/memory-box-julia-2000M.dat") if x.startswith("MEASURE ")])

data_20000M = data_20000M[(data_20000M[:, 1] == 0) | (data_20000M[:, 1] > 0.4*data_20000M[:, 1].max())]
data_15000M = data_15000M[(data_15000M[:, 1] == 0) | (data_15000M[:, 1] > 0.4*data_15000M[:, 1].max())]
data_10000M = data_10000M[(data_10000M[:, 1] == 0) | (data_10000M[:, 1] > 0.4*data_10000M[:, 1].max())]
data_9000M = data_9000M[(data_9000M[:, 1] == 0) | (data_9000M[:, 1] > 0.4*data_9000M[:, 1].max())]
data_8000M = data_8000M[(data_8000M[:, 1] == 0) | (data_8000M[:, 1] > 0.4*data_8000M[:, 1].max())]
data_7000M = data_7000M[(data_7000M[:, 1] == 0) | (data_7000M[:, 1] > 0.4*data_7000M[:, 1].max())]
data_6000M = data_6000M[(data_6000M[:, 1] == 0) | (data_6000M[:, 1] > 0.4*data_6000M[:, 1].max())]
data_5000M = data_5000M[(data_5000M[:, 1] == 0) | (data_5000M[:, 1] > 0.4*data_5000M[:, 1].max())]
data_4000M = data_4000M[(data_4000M[:, 1] == 0) | (data_4000M[:, 1] > 0.4*data_4000M[:, 1].max())]
data_3000M = data_3000M[(data_3000M[:, 1] == 0) | (data_3000M[:, 1] > 0.4*data_3000M[:, 1].max())]

ax.plot(data_50000M[:, 0], data_50000M[:, 1] / 1e9, c=c[0], label="50 GB")
ax.plot(data_20000M[:, 0], data_20000M[:, 1] / 1e9, c=c[1], label="20 GB")
ax.plot(data_15000M[:, 0], data_15000M[:, 1] / 1e9, c=c[2], label="15 GB")
ax.plot(data_10000M[:, 0], data_10000M[:, 1] / 1e9, c=c[3], label="10 GB")
ax.plot(data_9000M[:, 0], data_9000M[:, 1] / 1e9, c=c[4], label="9 GB")
ax.plot(data_8000M[:, 0], data_8000M[:, 1] / 1e9, c=c[5], label="8 GB")
ax.plot(data_7000M[:, 0], data_7000M[:, 1] / 1e9, c=c[6], label="7 GB")
ax.plot(data_6000M[:, 0], data_6000M[:, 1] / 1e9, c=c[7], label="6 GB")
ax.plot(data_5000M[:, 0], data_5000M[:, 1] / 1e9, c=c[8], label="5 GB")
ax.plot(data_4000M[:, 0], data_4000M[:, 1] / 1e9, c=c[9], label="4 GB")
ax.plot(data_3000M[:, 0], data_3000M[:, 1] / 1e9, c="#ff7800", label="3 GB")
ax.plot(data_2000M[:, 0], data_2000M[:, 1] / 1e9, c="#ff0006", label="2 GB")

ax.set_xlim(0, 80)
ax.set_ylim(0, 10)
ax.set_xlabel("time (seconds)")
ax.set_ylabel("memory (GB) in Unique Set Size (USS)")
ax.set_title("Julia 1.9.4")

ax.legend(title="cap on memory", loc="upper right")
fig.savefig("gcbox-julia.pdf")
